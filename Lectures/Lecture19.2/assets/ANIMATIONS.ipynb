# %% [markdown]
# Image paths are `../../figures/`. Change to `../figures/` when copying a cell into the lecture.

# %% [markdown]
# ## Elliptical rings
#
# <p align="center"><img src="../../figures/D10_elliptical_rings_landscape.gif" width="56%"></p>

# %% [markdown]
# Bessa's circular top and bottom rings replaced by ellipses, with a phase offset between their major axes.

# %% [markdown]
# **Breaking the rings' symmetry destroys coiling.** 9 of 67 designs coiled at all, and none were feasible.

# %% [markdown]
# A later 32-point sweep across the full registered box returned coilable=0 at every point, including
# two near-degenerate probes perturbed about one degree from circular. A systematic loss of the coiling
# mechanism across the whole tested box, not a scattered null.
#
# The status is INCONCLUSIVE rather than falsified because the guiding constraint surrogates were not
# demonstrably above chance, and the study's adequacy bar refuses a closed non-existence verdict on that
# evidence.
#
# Idea D10. Funnel n=67 to 9 coilable to 9 Riks-solved to 0 feasible.

# %% [markdown]
# ## The rectangular section
#
# <p align="center"><img src="../../figures/D6_run17_rectangle_native.gif" width="40%"></p>

# %% [markdown]
# An anisotropic rectangular longeron, short in the radial direction and long in the tangential one.

# %% [markdown]
# **The one that worked.** 6 feasible of 165, and the baseline every later idea is measured against.

# %% [markdown]
# It becomes run17_rectangle, the study's canonical anchor, later refined to 0.7704 kPa.
#
# Peak stress scales as E·w·c³/L². The depth c is capped by how tightly the design must coil, and the
# width w by the slenderness ≥ 10 beam-validity gate. A circle is isotropic, one parameter, so any circle
# stiff enough to carry load is too stiff to coil within the 2% strain budget. An elongated rectangle
# separates the two demands.
#
# Idea D6, verdict SUPPORTED and WORKS. Funnel n=165 to 149 coilable to 148 Riks-solved to 6 feasible,
# at 2.79x the Bessa point in this campaign.

# %% [markdown]
# ## Pre-twisted longerons
#
# <p align="center"><img src="../../figures/D1_pretwisted_negative_native.gif" width="38%"></p>

# %% [markdown]
# A helical pre-twist applied to each leg, on top of the full 7-parameter Bessa cross-section search.

# %% [markdown]
# **Pre-twist destroys coilability rather than helping it.** 6 of 46 designs coiled; none reached the second stage.

# %% [markdown]
# The registered test set itself a bar of at least 80 evaluations. A licence-server outage killed 26 of
# the planned runs, so the campaign finished below its own power bar and the status was recorded as
# INCONCLUSIVE rather than FALSIFIED.
#
# Idea D1. Funnel n=46 to 6 coilable to 0 Riks-solved to 0 feasible.

# %% [markdown]
# ## Tape-spring longerons
#
# <p align="center"><img src="../../figures/D25_tape_spring_landscape.gif" width="56%"></p>

# %% [markdown]
# The solid beam replaced by a thin-walled open circular arc, a tape-spring section, on the hypothesis that a localized elastic fold could escape the mast-scale curvature limit.

# %% [markdown]
# **The largest campaign in the study, 406 designs, and none feasible.**

# %% [markdown]
# The curvature that keeps the arc locally stable is the same curvature that sets its bending-strain
# floor. It can never be shallow enough to fold locally without buckling first, so strain follows
# ordinary beam bending at every geometry tested. A steel tape measure snaps the same way.
#
# Idea D25, verdict POWERED and REFUTED, mechanism localized elastic fold. Funnel n=406 to 176 coilable
# to 137 Riks-solved to 0 feasible.

# %% [markdown]
# ## Tensegrity longerons
#
# <p align="center"><img src="../../figures/D21_tensegrity_native.gif" width="40%"></p>

# %% [markdown]
# The bending longeron replaced by a pin-jointed, prestressed strut-and-cable assembly, taking its stiffness from prestress and geometry rather than from bending.

# %% [markdown]
# **The largest stress in the entire study, and disqualified for it.**

# %% [markdown]
# Maximum local strain came out near 9e-14. The members do not strain: the compression is achieved by
# rigid bars rotating about joints, so the object is a linkage and its buckling load is not on the same
# footing as elastic bending. The problem statement's apples-to-apples clause was written after this
# design exploited its absence.
#
# The critic rejected the run on a second ground: the 287x headline contradicted the run's own
# commissioned literature review, which had predicted a modest, saturating gain from prestress, and the
# gap was never reconciled.
#
# Idea D21, verdict SUPPORTED (DISQUALIFIED) and DEAD-END. Funnel n=45 to 45 coilable to 44 Riks-solved
# to 12 feasible.

# %% [markdown]
# ## The re-study under contact
#
# <p align="center"><img src="../../figures/restudy_floor_contact.gif" width="50%"></p>

# %% [markdown]
# Ground and disc contact were restored to the simulator on 2026-08-06, and five earlier families were re-examined under the new physics.

# %% [markdown]
# **One of the five was settled. Three were never tested.**

# %% [markdown]
# Tape-spring was settled: 330 designs over two campaigns, and the best of 28 decided reaches 21%
# compression against the 80% required. Tensegrity was stopped by the floor, energy up 86% with stress
# unchanged, and stays blocked on printability. Kresling, laced and chiral-shell were migrated to the
# new oracle but never tested under it.
#
# From the deck: do not read "we migrated it" as "we tested it". One design cannot settle a family, and
# the one design available is usually the winner of a search run carried out without contact.
